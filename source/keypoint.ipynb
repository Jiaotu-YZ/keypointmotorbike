# %%
import json
import os
import cv2
import matplotlib.pyplot as plt

# %%
keypoint_names = ['Head', 'Tail']

# Dictionary to convert rectangles classes into keypoint classes because keypoint classes should start with 0
rectangles2keypoints = {1:0, 2:1}

def converter(file_labels, file_image, keypoint_names):

    img = cv2.imread(file_image)
    img_w, img_h = img.shape[1], img.shape[0]
    
    with open(file_labels) as f:
        lines_txt = f.readlines()
        lines = []
        for line in lines_txt:
            lines.append([int(line.split()[0])] + [round(float(el), 5) for el in line.split()[1:]])

    bboxes = []
    keypoints = []

    # In this loop we convert normalized coordinates to absolute coordinates
    for line in lines:
        # Number 0 is a class of rectangles related to bounding boxes.
        if line[0] == 0:
            x_c, y_c, w, h = round(line[1] * img_w), round(line[2] * img_h), round(line[3] * img_w), round(line[4] * img_h)
            bboxes.append([round(x_c - w/2), round(y_c - h/2), round(x_c + w/2), round(y_c + h/2)])

        # Other numbers are the classes of rectangles related to keypoints.
        # After convertion, numbers of keypoint classes should start with 0, so we apply rectangles2keypoints dictionary to achieve that.
        # In our case:
        # 1 is rectangle for head keypoint, which is 0, so we convert 1 to 0;
        # 2 is rectangle for tail keypoint, which is 1, so we convert 2 to 1.
        if line[0] != 0:
            kp_id, x_c, y_c = rectangles2keypoints[line[0]], round(line[1] * img_w), round(line[2] * img_h)
            keypoints.append([kp_id, x_c, y_c])

    # In this loop we are iterating over each keypoint and looking to which bounding box it matches.
    # Thus, we are matching keypoints and corresponding bounding boxes.
    keypoints_sorted = [[[] for _ in keypoint_names] for _ in bboxes]
    for kp in keypoints:
        kp_id, kp_x, kp_y = kp[0], kp[1], kp[2]
        for bbox_idx, bbox in enumerate(bboxes):
            x1, y1, x2, y2 = bbox[0], bbox[1], bbox[2], bbox[3]
            if x1 < kp_x < x2 and y1 < kp_y < y2:
                keypoints_sorted[bbox_idx][kp_id] = [kp_x, kp_y, 1] # All keypoints are visible
                
    return bboxes, keypoints_sorted

# %%
def dump2json(bboxes, keypoints_sorted, file_json):
    annotations = {}
    annotations['bboxes'], annotations['keypoints'] = bboxes, keypoints_sorted
    with open(file_json, "w") as f:
        json.dump(annotations, f)

# %%
IMAGES = '../data/train/images'
LABELS = '../data/train/labels'
ANNOTATIONS = '../data/train/annotations'

files_names = [file.split('.jpg')[0] for file in os.listdir(IMAGES)]

for file in files_names:
    file_labels = os.path.join(LABELS, file + ".txt")
    file_image = os.path.join(IMAGES, file + ".jpg")
    print("Processing", file_labels, file_image)
    if os.path.exists(file_labels):
        print("Processing", file_labels, file_image)
        bboxes, keypoints_sorted = converter(file_labels, file_image, keypoint_names)
        dump2json(bboxes, keypoints_sorted, os.path.join(ANNOTATIONS, file + '.json'))
    else:
        print(f"Label file not found for {file_image}, skipping.")
# Out:
# Processing ../data/train/labels/image_3773_jpg.rf.8ebb5d29d7419ae805d37b9e3f62f624.txt ../data/train/images/image_3773_jpg.rf.8ebb5d29d7419ae805d37b9e3f62f624.jpg
# Processing ../data/train/labels/image_3773_jpg.rf.8ebb5d29d7419ae805d37b9e3f62f624.txt ../data/train/images/image_3773_jpg.rf.8ebb5d29d7419ae805d37b9e3f62f624.jpg
# Processing ../data/train/labels/image_1482_jpg.rf.87cd7eb14ffcfc1208e456e6bf7d6b42.txt ../data/train/images/image_1482_jpg.rf.87cd7eb14ffcfc1208e456e6bf7d6b42.jpg
# Processing ../data/train/labels/image_1482_jpg.rf.87cd7eb14ffcfc1208e456e6bf7d6b42.txt ../data/train/images/image_1482_jpg.rf.87cd7eb14ffcfc1208e456e6bf7d6b42.jpg
# Processing ../data/train/labels/image_2575_jpg.rf.55be035600ce3a3ba675659f65d9fe3a.txt ../data/train/images/image_2575_jpg.rf.55be035600ce3a3ba675659f65d9fe3a.jpg
# Processing ../data/train/labels/image_2575_jpg.rf.55be035600ce3a3ba675659f65d9fe3a.txt ../data/train/images/image_2575_jpg.rf.55be035600ce3a3ba675659f65d9fe3a.jpg
# Processing ../data/train/labels/image_3895_jpg.rf.e62d83e968bdc51fa25789c383e70449.txt ../data/train/images/image_3895_jpg.rf.e62d83e968bdc51fa25789c383e70449.jpg
# Processing ../data/train/labels/image_3895_jpg.rf.e62d83e968bdc51fa25789c383e70449.txt ../data/train/images/image_3895_jpg.rf.e62d83e968bdc51fa25789c383e70449.jpg
# Processing ../data/train/labels/image_3734_jpg.rf.0c193a1ed726775437da65b0ba65fa6a.txt ../data/train/images/image_3734_jpg.rf.0c193a1ed726775437da65b0ba65fa6a.jpg
# Processing ../data/train/labels/image_3734_jpg.rf.0c193a1ed726775437da65b0ba65fa6a.txt ../data/train/images/image_3734_jpg.rf.0c193a1ed726775437da65b0ba65fa6a.jpg
# Processing ../data/train/labels/image_2963_jpg.rf.619219efd8294246710e338547e80b82.txt ../data/train/images/image_2963_jpg.rf.619219efd8294246710e338547e80b82.jpg
# Processing ../data/train/labels/image_2963_jpg.rf.619219efd8294246710e338547e80b82.txt ../data/train/images/image_2963_jpg.rf.619219efd8294246710e338547e80b82.jpg
# Processing ../data/train/labels/image_1195_jpg.rf.4027249c413fabdb75a93f3141db8df8.txt ../data/train/images/image_1195_jpg.rf.4027249c413fabdb75a93f3141db8df8.jpg
# Processing ../data/train/labels/image_1195_jpg.rf.4027249c413fabdb75a93f3141db8df8.txt ../data/train/images/image_1195_jpg.rf.4027249c413fabdb75a93f3141db8df8.jpg
# Processing ../data/train/labels/image_4039_jpg.rf.9e60dc5978f7bd06c8b4a652416ea2c6.txt ../data/train/images/image_4039_jpg.rf.9e60dc5978f7bd06c8b4a652416ea2c6.jpg
# Processing ../data/train/labels/image_4039_jpg.rf.9e60dc5978f7bd06c8b4a652416ea2c6.txt ../data/train/images/image_4039_jpg.rf.9e60dc5978f7bd06c8b4a652416ea2c6.jpg
# Processing ../data/train/labels/image_3773_jpg.rf.274831c2c8cf80f2c35102413dd06a93.txt ../data/train/images/image_3773_jpg.rf.274831c2c8cf80f2c35102413dd06a93.jpg
# Processing ../data/train/labels/image_3773_jpg.rf.274831c2c8cf80f2c35102413dd06a93.txt ../data/train/images/image_3773_jpg.rf.274831c2c8cf80f2c35102413dd06a93.jpg
# Processing ../data/train/labels/image_2033_jpg.rf.70fb94616e7989e3c4ad8f3379bec808.txt ../data/train/images/image_2033_jpg.rf.70fb94616e7989e3c4ad8f3379bec808.jpg
# Processing ../data/train/labels/image_2033_jpg.rf.70fb94616e7989e3c4ad8f3379bec808.txt ../data/train/images/image_2033_jpg.rf.70fb94616e7989e3c4ad8f3379bec808.jpg
# Processing ../data/train/labels/image_1482_jpg.rf.1fe03dd3ca41d0c4effd9390ebd28400.txt ../data/train/images/image_1482_jpg.rf.1fe03dd3ca41d0c4effd9390ebd28400.jpg
# Processing ../data/train/labels/image_1482_jpg.rf.1fe03dd3ca41d0c4effd9390ebd28400.txt ../data/train/images/image_1482_jpg.rf.1fe03dd3ca41d0c4effd9390ebd28400.jpg
# Processing ../data/train/labels/image_60_jpg.rf.a00f4edb1a854da26d05b3642aed1835.txt ../data/train/images/image_60_jpg.rf.a00f4edb1a854da26d05b3642aed1835.jpg
# Processing ../data/train/labels/image_60_jpg.rf.a00f4edb1a854da26d05b3642aed1835.txt ../data/train/images/image_60_jpg.rf.a00f4edb1a854da26d05b3642aed1835.jpg
# Processing ../data/train/labels/image_3901_jpg.rf.a2123e2a2d990a7acfbd9e42dd5da31c.txt ../data/train/images/image_3901_jpg.rf.a2123e2a2d990a7acfbd9e42dd5da31c.jpg
# Processing ../data/train/labels/image_3901_jpg.rf.a2123e2a2d990a7acfbd9e42dd5da31c.txt ../data/train/images/image_3901_jpg.rf.a2123e2a2d990a7acfbd9e42dd5da31c.jpg
# Processing ../data/train/labels/image_2033_jpg.rf.1861dc2f0bd0447d3e354eeb66ae8a41.txt ../data/train/images/image_2033_jpg.rf.1861dc2f0bd0447d3e354eeb66ae8a41.jpg
# Processing ../data/train/labels/image_2033_jpg.rf.1861dc2f0bd0447d3e354eeb66ae8a41.txt ../data/train/images/image_2033_jpg.rf.1861dc2f0bd0447d3e354eeb66ae8a41.jpg
# Processing ../data/train/labels/image_4039_jpg.rf.f477c55e07d2f49052b742dea0ac1aad.txt ../data/train/images/image_4039_jpg.rf.f477c55e07d2f49052b742dea0ac1aad.jpg
# Processing ../data/train/labels/image_4039_jpg.rf.f477c55e07d2f49052b742dea0ac1aad.txt ../data/train/images/image_4039_jpg.rf.f477c55e07d2f49052b742dea0ac1aad.jpg
# Processing ../data/train/labels/image_60_jpg.rf.52e71a8058a159c0181f7154646f00c7.txt ../data/train/images/image_60_jpg.rf.52e71a8058a159c0181f7154646f00c7.jpg
# Processing ../data/train/labels/image_60_jpg.rf.52e71a8058a159c0181f7154646f00c7.txt ../data/train/images/image_60_jpg.rf.52e71a8058a159c0181f7154646f00c7.jpg
# Processing ../data/train/labels/image_599_jpg.rf.631f0427ca99d340d6492f3ddbc048d9.txt ../data/train/images/image_599_jpg.rf.631f0427ca99d340d6492f3ddbc048d9.jpg
# Processing ../data/train/labels/image_599_jpg.rf.631f0427ca99d340d6492f3ddbc048d9.txt ../data/train/images/image_599_jpg.rf.631f0427ca99d340d6492f3ddbc048d9.jpg
# Processing ../data/train/labels/image_2963_jpg.rf.b90f94e34fd70c900cb4e66e9668af40.txt ../data/train/images/image_2963_jpg.rf.b90f94e34fd70c900cb4e66e9668af40.jpg
# Processing ../data/train/labels/image_2963_jpg.rf.b90f94e34fd70c900cb4e66e9668af40.txt ../data/train/images/image_2963_jpg.rf.b90f94e34fd70c900cb4e66e9668af40.jpg
# Processing ../data/train/labels/image_733_jpg.rf.c555d65770c5132e4fadb84d8b8953f8.txt ../data/train/images/image_733_jpg.rf.c555d65770c5132e4fadb84d8b8953f8.jpg
# Processing ../data/train/labels/image_733_jpg.rf.c555d65770c5132e4fadb84d8b8953f8.txt ../data/train/images/image_733_jpg.rf.c555d65770c5132e4fadb84d8b8953f8.jpg
# Processing ../data/train/labels/image_2489_jpg.rf.7697ce8f76d739eacbd51ffc5f0effc0.txt ../data/train/images/image_2489_jpg.rf.7697ce8f76d739eacbd51ffc5f0effc0.jpg
# Processing ../data/train/labels/image_2489_jpg.rf.7697ce8f76d739eacbd51ffc5f0effc0.txt ../data/train/images/image_2489_jpg.rf.7697ce8f76d739eacbd51ffc5f0effc0.jpg
# Processing ../data/train/labels/image_901_jpg.rf.657ba51ab2d3e42632681504c2c9f234.txt ../data/train/images/image_901_jpg.rf.657ba51ab2d3e42632681504c2c9f234.jpg
# Processing ../data/train/labels/image_901_jpg.rf.657ba51ab2d3e42632681504c2c9f234.txt ../data/train/images/image_901_jpg.rf.657ba51ab2d3e42632681504c2c9f234.jpg
# Processing ../data/train/labels/image_3901_jpg.rf.ac204ce8e1eb9081a8a5258f619493c7.txt ../data/train/images/image_3901_jpg.rf.ac204ce8e1eb9081a8a5258f619493c7.jpg
# Processing ../data/train/labels/image_3901_jpg.rf.ac204ce8e1eb9081a8a5258f619493c7.txt ../data/train/images/image_3901_jpg.rf.ac204ce8e1eb9081a8a5258f619493c7.jpg
# Processing ../data/train/labels/image_3895_jpg.rf.524ea4a3685c65973ac12039d6f4f1ea.txt ../data/train/images/image_3895_jpg.rf.524ea4a3685c65973ac12039d6f4f1ea.jpg
# Processing ../data/train/labels/image_3895_jpg.rf.524ea4a3685c65973ac12039d6f4f1ea.txt ../data/train/images/image_3895_jpg.rf.524ea4a3685c65973ac12039d6f4f1ea.jpg
# Processing ../data/train/labels/image_2994_jpg.rf.d6b891de873f4b4d5f8120bc99a162d1.txt ../data/train/images/image_2994_jpg.rf.d6b891de873f4b4d5f8120bc99a162d1.jpg
# Processing ../data/train/labels/image_2994_jpg.rf.d6b891de873f4b4d5f8120bc99a162d1.txt ../data/train/images/image_2994_jpg.rf.d6b891de873f4b4d5f8120bc99a162d1.jpg
# Processing ../data/train/labels/image_3895_jpg.rf.f68d8867879645eeb50390637bcd7587.txt ../data/train/images/image_3895_jpg.rf.f68d8867879645eeb50390637bcd7587.jpg
# Processing ../data/train/labels/image_3895_jpg.rf.f68d8867879645eeb50390637bcd7587.txt ../data/train/images/image_3895_jpg.rf.f68d8867879645eeb50390637bcd7587.jpg
# Processing ../data/train/labels/image_901_jpg.rf.7af42b83362a6d1273034df4f6c25765.txt ../data/train/images/image_901_jpg.rf.7af42b83362a6d1273034df4f6c25765.jpg
# Processing ../data/train/labels/image_901_jpg.rf.7af42b83362a6d1273034df4f6c25765.txt ../data/train/images/image_901_jpg.rf.7af42b83362a6d1273034df4f6c25765.jpg
# Processing ../data/train/labels/image_2575_jpg.rf.680f9c025bbca015e93ace1ffd7f9f10.txt ../data/train/images/image_2575_jpg.rf.680f9c025bbca015e93ace1ffd7f9f10.jpg
# Processing ../data/train/labels/image_2575_jpg.rf.680f9c025bbca015e93ace1ffd7f9f10.txt ../data/train/images/image_2575_jpg.rf.680f9c025bbca015e93ace1ffd7f9f10.jpg
# Processing ../data/train/labels/image_599_jpg.rf.fd1b6f98c91735dc4a7afd042cf35c14.txt ../data/train/images/image_599_jpg.rf.fd1b6f98c91735dc4a7afd042cf35c14.jpg
# Processing ../data/train/labels/image_599_jpg.rf.fd1b6f98c91735dc4a7afd042cf35c14.txt ../data/train/images/image_599_jpg.rf.fd1b6f98c91735dc4a7afd042cf35c14.jpg
# Processing ../data/train/labels/image_3734_jpg.rf.2e67f460300055b3a29655d5edb6c612.txt ../data/train/images/image_3734_jpg.rf.2e67f460300055b3a29655d5edb6c612.jpg
# Processing ../data/train/labels/image_3734_jpg.rf.2e67f460300055b3a29655d5edb6c612.txt ../data/train/images/image_3734_jpg.rf.2e67f460300055b3a29655d5edb6c612.jpg
# Processing ../data/train/labels/image_2256_jpg.rf.e845e14beefd5b67574ea839930d0dd8.txt ../data/train/images/image_2256_jpg.rf.e845e14beefd5b67574ea839930d0dd8.jpg
# Processing ../data/train/labels/image_2256_jpg.rf.e845e14beefd5b67574ea839930d0dd8.txt ../data/train/images/image_2256_jpg.rf.e845e14beefd5b67574ea839930d0dd8.jpg
# Processing ../data/train/labels/image_2256_jpg.rf.c2fb49b94884e73550dbc9bc869d6a22.txt ../data/train/images/image_2256_jpg.rf.c2fb49b94884e73550dbc9bc869d6a22.jpg
# Processing ../data/train/labels/image_2256_jpg.rf.c2fb49b94884e73550dbc9bc869d6a22.txt ../data/train/images/image_2256_jpg.rf.c2fb49b94884e73550dbc9bc869d6a22.jpg
# Processing ../data/train/labels/image_901_jpg.rf.b2a1274a728a8f2d934119c29818ff45.txt ../data/train/images/image_901_jpg.rf.b2a1274a728a8f2d934119c29818ff45.jpg
# Processing ../data/train/labels/image_901_jpg.rf.b2a1274a728a8f2d934119c29818ff45.txt ../data/train/images/image_901_jpg.rf.b2a1274a728a8f2d934119c29818ff45.jpg
# Processing ../data/train/labels/image_1596_jpg.rf.1ccfb3510c5f84e7b535a70a529a98e6.txt ../data/train/images/image_1596_jpg.rf.1ccfb3510c5f84e7b535a70a529a98e6.jpg
# Processing ../data/train/labels/image_1596_jpg.rf.1ccfb3510c5f84e7b535a70a529a98e6.txt ../data/train/images/image_1596_jpg.rf.1ccfb3510c5f84e7b535a70a529a98e6.jpg
# Processing ../data/train/labels/image_439_jpg.rf.29842ca56c736f390c6a9d57c58fd382.txt ../data/train/images/image_439_jpg.rf.29842ca56c736f390c6a9d57c58fd382.jpg
# Processing ../data/train/labels/image_439_jpg.rf.29842ca56c736f390c6a9d57c58fd382.txt ../data/train/images/image_439_jpg.rf.29842ca56c736f390c6a9d57c58fd382.jpg
# Processing ../data/train/labels/image_3734_jpg.rf.60f1699852a459f1ba03bea08204fe1b.txt ../data/train/images/image_3734_jpg.rf.60f1699852a459f1ba03bea08204fe1b.jpg
# Processing ../data/train/labels/image_3734_jpg.rf.60f1699852a459f1ba03bea08204fe1b.txt ../data/train/images/image_3734_jpg.rf.60f1699852a459f1ba03bea08204fe1b.jpg
# Processing ../data/train/labels/image_3058_jpg.rf.a5a3b8107ac8c5cdca71dda92915d47e.txt ../data/train/images/image_3058_jpg.rf.a5a3b8107ac8c5cdca71dda92915d47e.jpg
# Processing ../data/train/labels/image_3058_jpg.rf.a5a3b8107ac8c5cdca71dda92915d47e.txt ../data/train/images/image_3058_jpg.rf.a5a3b8107ac8c5cdca71dda92915d47e.jpg
# Processing ../data/train/labels/image_439_jpg.rf.35a02dd9c3af16a5f2d10f10bb511394.txt ../data/train/images/image_439_jpg.rf.35a02dd9c3af16a5f2d10f10bb511394.jpg
# Processing ../data/train/labels/image_439_jpg.rf.35a02dd9c3af16a5f2d10f10bb511394.txt ../data/train/images/image_439_jpg.rf.35a02dd9c3af16a5f2d10f10bb511394.jpg
# Processing ../data/train/labels/image_2819_jpg.rf.0dda268907c9be6f78d1564541adfa47.txt ../data/train/images/image_2819_jpg.rf.0dda268907c9be6f78d1564541adfa47.jpg
# Processing ../data/train/labels/image_2819_jpg.rf.0dda268907c9be6f78d1564541adfa47.txt ../data/train/images/image_2819_jpg.rf.0dda268907c9be6f78d1564541adfa47.jpg
# Processing ../data/train/labels/image_599_jpg.rf.8a6e63610e7f4ab76a4fe4383eaf2dcc.txt ../data/train/images/image_599_jpg.rf.8a6e63610e7f4ab76a4fe4383eaf2dcc.jpg
# Processing ../data/train/labels/image_599_jpg.rf.8a6e63610e7f4ab76a4fe4383eaf2dcc.txt ../data/train/images/image_599_jpg.rf.8a6e63610e7f4ab76a4fe4383eaf2dcc.jpg
# Processing ../data/train/labels/image_2575_jpg.rf.691001181403f9bebde233c517374107.txt ../data/train/images/image_2575_jpg.rf.691001181403f9bebde233c517374107.jpg
# Processing ../data/train/labels/image_2575_jpg.rf.691001181403f9bebde233c517374107.txt ../data/train/images/image_2575_jpg.rf.691001181403f9bebde233c517374107.jpg
# Processing ../data/train/labels/image_2489_jpg.rf.71650f725d9d6d25ffb983c3b0d28009.txt ../data/train/images/image_2489_jpg.rf.71650f725d9d6d25ffb983c3b0d28009.jpg
# Processing ../data/train/labels/image_2489_jpg.rf.71650f725d9d6d25ffb983c3b0d28009.txt ../data/train/images/image_2489_jpg.rf.71650f725d9d6d25ffb983c3b0d28009.jpg
# Processing ../data/train/labels/image_2966_jpg.rf.b6e4aa05e5489c37b1913b8a93aecc75.txt ../data/train/images/image_2966_jpg.rf.b6e4aa05e5489c37b1913b8a93aecc75.jpg
# Processing ../data/train/labels/image_2966_jpg.rf.b6e4aa05e5489c37b1913b8a93aecc75.txt ../data/train/images/image_2966_jpg.rf.b6e4aa05e5489c37b1913b8a93aecc75.jpg
# Processing ../data/train/labels/image_1482_jpg.rf.f3a60525eff3515407caa2d886425c3c.txt ../data/train/images/image_1482_jpg.rf.f3a60525eff3515407caa2d886425c3c.jpg
# Processing ../data/train/labels/image_1482_jpg.rf.f3a60525eff3515407caa2d886425c3c.txt ../data/train/images/image_1482_jpg.rf.f3a60525eff3515407caa2d886425c3c.jpg
# Processing ../data/train/labels/image_2489_jpg.rf.609a847109303ccd94280b51a20c5a1d.txt ../data/train/images/image_2489_jpg.rf.609a847109303ccd94280b51a20c5a1d.jpg
# Processing ../data/train/labels/image_2489_jpg.rf.609a847109303ccd94280b51a20c5a1d.txt ../data/train/images/image_2489_jpg.rf.609a847109303ccd94280b51a20c5a1d.jpg
# Processing ../data/train/labels/image_1195_jpg.rf.7448ff2c2d6c5314b247618a6e13ace5.txt ../data/train/images/image_1195_jpg.rf.7448ff2c2d6c5314b247618a6e13ace5.jpg
# Processing ../data/train/labels/image_1195_jpg.rf.7448ff2c2d6c5314b247618a6e13ace5.txt ../data/train/images/image_1195_jpg.rf.7448ff2c2d6c5314b247618a6e13ace5.jpg
# Processing ../data/train/labels/image_3901_jpg.rf.cd2fa806e1ccd443145df975fc325320.txt ../data/train/images/image_3901_jpg.rf.cd2fa806e1ccd443145df975fc325320.jpg
# Processing ../data/train/labels/image_3901_jpg.rf.cd2fa806e1ccd443145df975fc325320.txt ../data/train/images/image_3901_jpg.rf.cd2fa806e1ccd443145df975fc325320.jpg
# Processing ../data/train/labels/image_3058_jpg.rf.d2f581f6c80669b398ed2b6415faa837.txt ../data/train/images/image_3058_jpg.rf.d2f581f6c80669b398ed2b6415faa837.jpg
# Processing ../data/train/labels/image_3058_jpg.rf.d2f581f6c80669b398ed2b6415faa837.txt ../data/train/images/image_3058_jpg.rf.d2f581f6c80669b398ed2b6415faa837.jpg
# Processing ../data/train/labels/image_60_jpg.rf.670ed37517d0cfb642818864833eee31.txt ../data/train/images/image_60_jpg.rf.670ed37517d0cfb642818864833eee31.jpg
# Processing ../data/train/labels/image_60_jpg.rf.670ed37517d0cfb642818864833eee31.txt ../data/train/images/image_60_jpg.rf.670ed37517d0cfb642818864833eee31.jpg
# Processing ../data/train/labels/image_2819_jpg.rf.4f89b61f428151ae09a66fd599130472.txt ../data/train/images/image_2819_jpg.rf.4f89b61f428151ae09a66fd599130472.jpg
# Processing ../data/train/labels/image_2819_jpg.rf.4f89b61f428151ae09a66fd599130472.txt ../data/train/images/image_2819_jpg.rf.4f89b61f428151ae09a66fd599130472.jpg
# Processing ../data/train/labels/image_2033_jpg.rf.a16492f7bcfefa41d5ebd4f3f145cd7a.txt ../data/train/images/image_2033_jpg.rf.a16492f7bcfefa41d5ebd4f3f145cd7a.jpg
# Processing ../data/train/labels/image_2033_jpg.rf.a16492f7bcfefa41d5ebd4f3f145cd7a.txt ../data/train/images/image_2033_jpg.rf.a16492f7bcfefa41d5ebd4f3f145cd7a.jpg
# Processing ../data/train/labels/image_439_jpg.rf.57e53019f94886a91edcf9538c67bdf4.txt ../data/train/images/image_439_jpg.rf.57e53019f94886a91edcf9538c67bdf4.jpg
# Processing ../data/train/labels/image_439_jpg.rf.57e53019f94886a91edcf9538c67bdf4.txt ../data/train/images/image_439_jpg.rf.57e53019f94886a91edcf9538c67bdf4.jpg
# Processing ../data/train/labels/image_1596_jpg.rf.0e2ac46249af44ee9c4ea320040fd1f4.txt ../data/train/images/image_1596_jpg.rf.0e2ac46249af44ee9c4ea320040fd1f4.jpg
# Processing ../data/train/labels/image_1596_jpg.rf.0e2ac46249af44ee9c4ea320040fd1f4.txt ../data/train/images/image_1596_jpg.rf.0e2ac46249af44ee9c4ea320040fd1f4.jpg
# Processing ../data/train/labels/image_2966_jpg.rf.258b73b4366700ba8b547e0ab45075d5.txt ../data/train/images/image_2966_jpg.rf.258b73b4366700ba8b547e0ab45075d5.jpg
# Processing ../data/train/labels/image_2966_jpg.rf.258b73b4366700ba8b547e0ab45075d5.txt ../data/train/images/image_2966_jpg.rf.258b73b4366700ba8b547e0ab45075d5.jpg
# Processing ../data/train/labels/image_3773_jpg.rf.f6348dc985d00f9637eb281c42b46ec5.txt ../data/train/images/image_3773_jpg.rf.f6348dc985d00f9637eb281c42b46ec5.jpg
# Processing ../data/train/labels/image_3773_jpg.rf.f6348dc985d00f9637eb281c42b46ec5.txt ../data/train/images/image_3773_jpg.rf.f6348dc985d00f9637eb281c42b46ec5.jpg
# Processing ../data/train/labels/image_1195_jpg.rf.7818806193c9346e16e7b1faca8fa504.txt ../data/train/images/image_1195_jpg.rf.7818806193c9346e16e7b1faca8fa504.jpg
# Processing ../data/train/labels/image_1195_jpg.rf.7818806193c9346e16e7b1faca8fa504.txt ../data/train/images/image_1195_jpg.rf.7818806193c9346e16e7b1faca8fa504.jpg
# Processing ../data/train/labels/image_2966_jpg.rf.529b7ceb6b78ce3a79be5c2594458224.txt ../data/train/images/image_2966_jpg.rf.529b7ceb6b78ce3a79be5c2594458224.jpg
# Processing ../data/train/labels/image_2966_jpg.rf.529b7ceb6b78ce3a79be5c2594458224.txt ../data/train/images/image_2966_jpg.rf.529b7ceb6b78ce3a79be5c2594458224.jpg
# Processing ../data/train/labels/image_2994_jpg.rf.c6f5843da3cf4139072476ef69d5579d.txt ../data/train/images/image_2994_jpg.rf.c6f5843da3cf4139072476ef69d5579d.jpg
# Processing ../data/train/labels/image_2994_jpg.rf.c6f5843da3cf4139072476ef69d5579d.txt ../data/train/images/image_2994_jpg.rf.c6f5843da3cf4139072476ef69d5579d.jpg
# Processing ../data/train/labels/image_2256_jpg.rf.6a70eddd0cbc2ab3416e24c380ed4dc5.txt ../data/train/images/image_2256_jpg.rf.6a70eddd0cbc2ab3416e24c380ed4dc5.jpg
# Processing ../data/train/labels/image_2256_jpg.rf.6a70eddd0cbc2ab3416e24c380ed4dc5.txt ../data/train/images/image_2256_jpg.rf.6a70eddd0cbc2ab3416e24c380ed4dc5.jpg
# Processing ../data/train/labels/image_733_jpg.rf.79ca10a98366925f1418807d63f38c31.txt ../data/train/images/image_733_jpg.rf.79ca10a98366925f1418807d63f38c31.jpg
# Processing ../data/train/labels/image_733_jpg.rf.79ca10a98366925f1418807d63f38c31.txt ../data/train/images/image_733_jpg.rf.79ca10a98366925f1418807d63f38c31.jpg
# Processing ../data/train/labels/image_2994_jpg.rf.447f1d1b05479e21b2951ec38fd0eba2.txt ../data/train/images/image_2994_jpg.rf.447f1d1b05479e21b2951ec38fd0eba2.jpg
# Processing ../data/train/labels/image_2994_jpg.rf.447f1d1b05479e21b2951ec38fd0eba2.txt ../data/train/images/image_2994_jpg.rf.447f1d1b05479e21b2951ec38fd0eba2.jpg
# Processing ../data/train/labels/image_3058_jpg.rf.0249b8f3022e5acfe6de927347b7bb24.txt ../data/train/images/image_3058_jpg.rf.0249b8f3022e5acfe6de927347b7bb24.jpg
# Processing ../data/train/labels/image_3058_jpg.rf.0249b8f3022e5acfe6de927347b7bb24.txt ../data/train/images/image_3058_jpg.rf.0249b8f3022e5acfe6de927347b7bb24.jpg
# Processing ../data/train/labels/image_4039_jpg.rf.db919e818544451e4529ed023f74ff03.txt ../data/train/images/image_4039_jpg.rf.db919e818544451e4529ed023f74ff03.jpg
# Processing ../data/train/labels/image_4039_jpg.rf.db919e818544451e4529ed023f74ff03.txt ../data/train/images/image_4039_jpg.rf.db919e818544451e4529ed023f74ff03.jpg

# %%
IMAGES = '../data/test/images'
LABELS = '../data/test/labels'
ANNOTATIONS = '../data/test/annotations'

files_names = [file.split('.jpg')[0] for file in os.listdir(IMAGES)]

for file in files_names:
    file_labels = os.path.join(LABELS, file + ".txt")
    file_image = os.path.join(IMAGES, file + ".jpg")
    print("Processing", file_labels, file_image)
    if os.path.exists(file_labels):
        print("Processing", file_labels, file_image)
        bboxes, keypoints_sorted = converter(file_labels, file_image, keypoint_names)
        dump2json(bboxes, keypoints_sorted, os.path.join(ANNOTATIONS, file + '.json'))
    else:
        print(f"Label file not found for {file_image}, skipping.")
# Out:
# Processing ../data/test/labels/image_2953_jpg.rf.79dd93ed80660413ef52d9ad66a6e99d.txt ../data/test/images/image_2953_jpg.rf.79dd93ed80660413ef52d9ad66a6e99d.jpg
# Processing ../data/test/labels/image_2953_jpg.rf.79dd93ed80660413ef52d9ad66a6e99d.txt ../data/test/images/image_2953_jpg.rf.79dd93ed80660413ef52d9ad66a6e99d.jpg
# Processing ../data/test/labels/image_3820_jpg.rf.d4cd792f062c053f515940618eb6a073.txt ../data/test/images/image_3820_jpg.rf.d4cd792f062c053f515940618eb6a073.jpg
# Processing ../data/test/labels/image_3820_jpg.rf.d4cd792f062c053f515940618eb6a073.txt ../data/test/images/image_3820_jpg.rf.d4cd792f062c053f515940618eb6a073.jpg
# Processing ../data/test/labels/image_3791_jpg.rf.15a5f89d089c59e5564bd1f218f55cee.txt ../data/test/images/image_3791_jpg.rf.15a5f89d089c59e5564bd1f218f55cee.jpg
# Processing ../data/test/labels/image_3791_jpg.rf.15a5f89d089c59e5564bd1f218f55cee.txt ../data/test/images/image_3791_jpg.rf.15a5f89d089c59e5564bd1f218f55cee.jpg
# Processing ../data/test/labels/image_543_jpg.rf.fbb182230716b5c3bab59cbf244f3fcf.txt ../data/test/images/image_543_jpg.rf.fbb182230716b5c3bab59cbf244f3fcf.jpg
# Processing ../data/test/labels/image_543_jpg.rf.fbb182230716b5c3bab59cbf244f3fcf.txt ../data/test/images/image_543_jpg.rf.fbb182230716b5c3bab59cbf244f3fcf.jpg
# Processing ../data/test/labels/image_4132_jpg.rf.499b38a1c29150ec54c42ee63ba087bb.txt ../data/test/images/image_4132_jpg.rf.499b38a1c29150ec54c42ee63ba087bb.jpg
# Processing ../data/test/labels/image_4132_jpg.rf.499b38a1c29150ec54c42ee63ba087bb.txt ../data/test/images/image_4132_jpg.rf.499b38a1c29150ec54c42ee63ba087bb.jpg
# Processing ../data/test/labels/image_2187_jpg.rf.15f2b506123b4a079276d88f1fafb2e4.txt ../data/test/images/image_2187_jpg.rf.15f2b506123b4a079276d88f1fafb2e4.jpg
# Processing ../data/test/labels/image_2187_jpg.rf.15f2b506123b4a079276d88f1fafb2e4.txt ../data/test/images/image_2187_jpg.rf.15f2b506123b4a079276d88f1fafb2e4.jpg

# %%
IMAGES = '../data/valid/images'
LABELS = '../data/valid/labels'
ANNOTATIONS = '../data/valid/annotations'

files_names = [file.split('.jpg')[0] for file in os.listdir(IMAGES)]

for file in files_names:
    file_labels = os.path.join(LABELS, file + ".txt")
    file_image = os.path.join(IMAGES, file + ".jpg")
    print("Processing", file_labels, file_image)
    if os.path.exists(file_labels):
        print("Processing", file_labels, file_image)
        bboxes, keypoints_sorted = converter(file_labels, file_image, keypoint_names)
        dump2json(bboxes, keypoints_sorted, os.path.join(ANNOTATIONS, file + '.json'))
    else:
        print(f"Label file not found for {file_image}, skipping.")
# Out:
# Processing ../data/valid/labels/image_3218_jpg.rf.55f294057174508ba40fa4f44d0395ee.txt ../data/valid/images/image_3218_jpg.rf.55f294057174508ba40fa4f44d0395ee.jpg
# Processing ../data/valid/labels/image_3218_jpg.rf.55f294057174508ba40fa4f44d0395ee.txt ../data/valid/images/image_3218_jpg.rf.55f294057174508ba40fa4f44d0395ee.jpg
# Processing ../data/valid/labels/image_759_jpg.rf.4a2ceccb0c2bad6582a79c1cb6e7c8cf.txt ../data/valid/images/image_759_jpg.rf.4a2ceccb0c2bad6582a79c1cb6e7c8cf.jpg
# Processing ../data/valid/labels/image_759_jpg.rf.4a2ceccb0c2bad6582a79c1cb6e7c8cf.txt ../data/valid/images/image_759_jpg.rf.4a2ceccb0c2bad6582a79c1cb6e7c8cf.jpg
# Processing ../data/valid/labels/image_602_jpg.rf.ad12e7b0c4c167ba3a5e2e700ff15f0f.txt ../data/valid/images/image_602_jpg.rf.ad12e7b0c4c167ba3a5e2e700ff15f0f.jpg
# Processing ../data/valid/labels/image_602_jpg.rf.ad12e7b0c4c167ba3a5e2e700ff15f0f.txt ../data/valid/images/image_602_jpg.rf.ad12e7b0c4c167ba3a5e2e700ff15f0f.jpg
